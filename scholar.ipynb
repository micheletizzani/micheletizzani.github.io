# %%
from scholarly import scholarly

# Search for papers on the topic "optimizing rag"
query = 'Michele Tizzani'

# Perform the search
search_results = scholarly.search_pubs(query)

scholarly.pprint(next(search_results))
# Out:
# b"{'author_id': ['bxijW04AAAAJ', 'iXfwdp4AAAAJ', 'duBif0oAAAAJ', 'whAXlGoAAAAJ'],\n 'bib': {'abstract': 'Background The exposure and consumption of information '\n                     'during epidemic outbreaks may  alter people\xe2\x80\x99s risk '\n                     'perception and trigger behavioral changes, which can '\n                     'ultimately affect the',\n         'author': ['N Gozzi', 'M Tizzani', 'M Starnini', 'F Ciulla'],\n         'pub_year': '2020',\n         'title': 'Collective response to media coverage of the COVID-19 '\n                  'pandemic on Reddit and Wikipedia: mixed-methods analysis',\n         'venue': 'Journal of medical \xe2\x80\xa6'},\n 'citedby_url': '/scholar?cites=6622088579287130844&as_sdt=5,33&sciodt=0,33&hl=en',\n 'eprint_url': 'https://www.jmir.org/2020/10/e21597/',\n 'filled': False,\n 'gsrank': 1,\n 'num_citations': 181,\n 'pub_url': 'https://www.jmir.org/2020/10/e21597/',\n 'source': 'PUBLICATION_SEARCH_SNIPPET',\n 'url_add_sclib': '/citations?hl=en&xsrf=&continue=/scholar%3Fq%3DMichele%2BTizzani%26hl%3Den%26as_sdt%3D0,33&citilm=1&update_op=library_add&info=3KKUP3pi5lsJ&ei=oxUWaYXvEJvJieoPmpGLiQg&json=',\n 'url_related_articles': '/scholar?q=related:3KKUP3pi5lsJ:scholar.google.com/&scioq=Michele+Tizzani&hl=en&as_sdt=0,33',\n 'url_scholarbib': '/scholar?hl=en&q=info:3KKUP3pi5lsJ:scholar.google.com/&output=cite&scirp=0&hl=en'}"

# %%
search_query = scholarly.search_author('Steven A Cholewiak')
author = scholarly.fill(next(search_query))
print(author)
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# Cell In[6], line 2
#       1 search_query = scholarly.search_author('Steven A Cholewiak')
# ----> 2 author = scholarly.fill(next(search_query))
#       3 print(author)
#
# StopIteration:

# %%
search_query
# Out:
# <generator object Navigator.search_authors at 0x10fd3b880>
